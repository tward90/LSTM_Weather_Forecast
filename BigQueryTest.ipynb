# %%
# Load BigQuery Magic Commands
# %pip install --upgrade google-cloud-bigquery[bqstorage,pandas]
# %load_ext google.cloud.bigquery
# Out:
# Requirement already up-to-date: google-cloud-bigquery[bqstorage,pandas] in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (2.1.0)
# Requirement already satisfied, skipping upgrade: google-resumable-media<2.0dev,>=0.6.0 in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (from google-cloud-bigquery[bqstorage,pandas]) (1.1.0)
# Requirement already satisfied, skipping upgrade: proto-plus>=1.10.0 in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (from google-cloud-bigquery[bqstorage,pandas]) (1.10.1)
# Requirement already satisfied, skipping upgrade: six<2.0.0dev,>=1.13.0 in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (from google-cloud-bigquery[bqstorage,pandas]) (1.15.0)
# Requirement already satisfied, skipping upgrade: google-api-core[grpc]<2.0.0dev,>=1.22.2 in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (from google-cloud-bigquery[bqstorage,pandas]) (1.22.4)
# Requirement already satisfied, skipping upgrade: google-cloud-core<2.0dev,>=1.4.1 in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (from google-cloud-bigquery[bqstorage,pandas]) (1.4.3)
# Requirement already satisfied, skipping upgrade: grpcio<2.0dev,>=1.32.0; extra == "bqstorage" in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (from google-cloud-bigquery[bqstorage,pandas]) (1.32.0)
# Requirement already satisfied, skipping upgrade: google-cloud-bigquery-storage<3.0.0dev,>=2.0.0; extra == "bqstorage" in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (from google-cloud-bigquery[bqstorage,pandas]) (2.0.0)
# Requirement already satisfied, skipping upgrade: pyarrow<2.0dev,>=1.0.0; extra == "bqstorage" in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (from google-cloud-bigquery[bqstorage,pandas]) (1.0.1)
# Requirement already satisfied, skipping upgrade: pandas>=0.23.0; extra == "pandas" in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (from google-cloud-bigquery[bqstorage,pandas]) (1.1.3)
# Requirement already satisfied, skipping upgrade: google-crc32c<2.0dev,>=1.0; python_version >= "3.5" in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (from google-resumable-media<2.0dev,>=0.6.0->google-cloud-bigquery[bqstorage,pandas]) (1.0.0)
# Requirement already satisfied, skipping upgrade: protobuf>=3.12.0 in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (from proto-plus>=1.10.0->google-cloud-bigquery[bqstorage,pandas]) (3.13.0)
# Requirement already satisfied, skipping upgrade: setuptools>=34.0.0 in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-bigquery[bqstorage,pandas]) (50.3.0.post20201006)
# Requirement already satisfied, skipping upgrade: google-auth<2.0dev,>=1.21.1 in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-bigquery[bqstorage,pandas]) (1.22.1)
# Requirement already satisfied, skipping upgrade: requests<3.0.0dev,>=2.18.0 in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-bigquery[bqstorage,pandas]) (2.24.0)
# Requirement already satisfied, skipping upgrade: pytz in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-bigquery[bqstorage,pandas]) (2020.1)
# Requirement already satisfied, skipping upgrade: googleapis-common-protos<2.0dev,>=1.6.0 in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-bigquery[bqstorage,pandas]) (1.52.0)
# Requirement already satisfied, skipping upgrade: libcst>=0.2.5 in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (from google-cloud-bigquery-storage<3.0.0dev,>=2.0.0; extra == "bqstorage"->google-cloud-bigquery[bqstorage,pandas]) (0.3.12)
# Requirement already satisfied, skipping upgrade: numpy>=1.14 in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (from pyarrow<2.0dev,>=1.0.0; extra == "bqstorage"->google-cloud-bigquery[bqstorage,pandas]) (1.19.2)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (from pandas>=0.23.0; extra == "pandas"->google-cloud-bigquery[bqstorage,pandas]) (2.8.1)
# Requirement already satisfied, skipping upgrade: cffi>=1.0.0 in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (from google-crc32c<2.0dev,>=1.0; python_version >= "3.5"->google-resumable-media<2.0dev,>=0.6.0->google-cloud-bigquery[bqstorage,pandas]) (1.14.3)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3.5" in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (from google-auth<2.0dev,>=1.21.1->google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-bigquery[bqstorage,pandas]) (4.6)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (from google-auth<2.0dev,>=1.21.1->google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-bigquery[bqstorage,pandas]) (4.1.1)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (from google-auth<2.0dev,>=1.21.1->google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-bigquery[bqstorage,pandas]) (0.2.8)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-bigquery[bqstorage,pandas]) (2.10)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-bigquery[bqstorage,pandas]) (1.25.10)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-bigquery[bqstorage,pandas]) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-bigquery[bqstorage,pandas]) (2020.6.20)
# Requirement already satisfied, skipping upgrade: typing-extensions>=3.7.4.2 in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (from libcst>=0.2.5->google-cloud-bigquery-storage<3.0.0dev,>=2.0.0; extra == "bqstorage"->google-cloud-bigquery[bqstorage,pandas]) (3.7.4.3)
# Requirement already satisfied, skipping upgrade: typing-inspect>=0.4.0 in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (from libcst>=0.2.5->google-cloud-bigquery-storage<3.0.0dev,>=2.0.0; extra == "bqstorage"->google-cloud-bigquery[bqstorage,pandas]) (0.6.0)
# Requirement already satisfied, skipping upgrade: pyyaml>=5.2 in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (from libcst>=0.2.5->google-cloud-bigquery-storage<3.0.0dev,>=2.0.0; extra == "bqstorage"->google-cloud-bigquery[bqstorage,pandas]) (5.3.1)
# Requirement already satisfied, skipping upgrade: pycparser in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (from cffi>=1.0.0->google-crc32c<2.0dev,>=1.0; python_version >= "3.5"->google-resumable-media<2.0dev,>=0.6.0->google-cloud-bigquery[bqstorage,pandas]) (2.20)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.3 in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (from rsa<5,>=3.1.4; python_version >= "3.5"->google-auth<2.0dev,>=1.21.1->google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-bigquery[bqstorage,pandas]) (0.4.8)
# Requirement already satisfied, skipping upgrade: mypy-extensions>=0.3.0 in /Users/tyler/opt/anaconda3/envs/BigQuery/lib/python3.7/site-packages (from typing-inspect>=0.4.0->libcst>=0.2.5->google-cloud-bigquery-storage<3.0.0dev,>=2.0.0; extra == "bqstorage"->google-cloud-bigquery[bqstorage,pandas]) (0.4.3)
# Note: you may need to restart the kernel to use updated packages.
# The google.cloud.bigquery extension is already loaded. To reload it, use:
#   %reload_ext google.cloud.bigquery

# %%
# %%bigquery
# SELECT
#     source_year AS year,
#     COUNT(is_male) AS birth_count
# FROM `bigquery-public-data.samples.natality`
# GROUP BY year
# ORDER BY year DESC
# LIMIT 15
# Out:
#     year  birth_count
# 0   2008      4255156
# 1   2007      4324008
# 2   2006      4273225
# 3   2005      4145619
# 4   2004      4118907
# 5   2003      4096092
# 6   2002      4027376
# 7   2001      4031531
# 8   2000      4063823
# 9   1999      3963465
# 10  1998      3945192
# 11  1997      3884329
# 12  1996      3894874
# 13  1995      3903012
# 14  1994      3956925

# %%
# %%bigquery total_births
# SELECT
#     source_year AS year,
#     COUNT(is_male) AS birth_count
# FROM `bigquery-public-data.samples.natality`
# GROUP BY year
# ORDER BY year DESC
# LIMIT 15

# %%
# Out:
#     year  birth_count
# 0   2008      4255156
# 1   2007      4324008
# 2   2006      4273225
# 3   2005      4145619
# 4   2004      4118907
# 5   2003      4096092
# 6   2002      4027376
# 7   2001      4031531
# 8   2000      4063823
# 9   1999      3963465
# 10  1998      3945192
# 11  1997      3884329
# 12  1996      3894874
# 13  1995      3903012
# 14  1994      3956925
