# %%
    # import pandas as pd
    
    # import tensorflow as tf
    # from matplotlib import pyplot as plt
    # from sklearn.preprocessing import LabelEncoder
    # from sklearn.preprocessing import MinMaxScaler
    # from sklearn.model_selection import train_test_split
    # from sklearn.metrics import mean_squared_error
    # from tensorflow.keras.models import Sequential
    
    # from tensorflow.keras.layers import LSTM
    # from tensorflow.keras.preprocessing import timeseries_dataset_from_array

    # from hyperas import optim
    # from hyperas.distributions import choice, uniform
    # from hyperopt import Trials, STATUS_OK, tpe

# %%
def data():

    import numpy as np
    from keras.datasets import mnist
    from keras.utils import np_utils

    x_train = np.zeros(100)
    x_test = np.zeros(100)
    y_train = np.zeros(100)
    y_test = np.zeros(100)
    
    (x_train, y_train), (x_test, y_test) = mnist.load_data()
    x_train = x_train.reshape(60000, 784)
    x_test = x_test.reshape(10000, 784)
    x_train = x_train.astype('float32')
    x_test = x_test.astype('float32')
    x_train /= 255
    x_test /= 255
    nb_classes = 10
    y_train = np_utils.to_categorical(y_train, nb_classes)
    y_test = np_utils.to_categorical(y_test, nb_classes)
    return x_train, y_train, x_test, y_test

    return x_train, y_train, x_test, y_test

# %%
def create_model(x_train, y_train, x_test, y_test):

    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import Activation, Dense, Dropout
    from hyperas.distributions import uniform
    from hyperopt import STATUS_OK
    from keras.datasets import mnist
    from keras.utils import np_utils


    model = Sequential()
    model.add(Dense(512, input_shape=(784,)))
    model.add(Activation('relu'))
    model.add(Dropout({{uniform(0, 1)}}))
    model.add(Dense({{choice([256, 512, 1024])}}))
    model.add(Activation({{choice(['relu', 'sigmoid'])}}))
    model.add(Dropout({{uniform(0, 1)}}))

    # If we choose 'four', add an additional fourth layer
    if {{choice(['three', 'four'])}} == 'four':
        model.add(Dense(100))

        # We can also choose between complete sets of layers

        model.add({{choice([Dropout(0.5), Activation('linear')])}})
        model.add(Activation('relu'))

    model.add(Dense(10))
    model.add(Activation('softmax'))

    model.compile(loss='categorical_crossentropy', metrics=['accuracy'],
                  optimizer={{choice(['rmsprop', 'adam', 'sgd'])}})

    result = model.fit(x_train, y_train,
              batch_size={{choice([64, 128])}},
              epochs=2,
              verbose=2,
              validation_split=0.1)
    #get the highest validation accuracy of the training epochs
    validation_acc = np.amax(result.history['val_accuracy']) 
    print('Best validation acc of epoch:', validation_acc)
    return {'loss': -validation_acc, 'status': STATUS_OK, 'model': model}

# %%
if __name__ == '__main__':
    from hyperas import optim
    from hyperopt import Trials, tpe
    
    best_run, best_model = optim.minimize(model=create_model,
                                          data=data,
                                          algo=tpe.suggest,
                                          max_evals=5,
                                          trials=Trials(),
                                          notebook_name='test')
    X_train, Y_train, X_test, Y_test = data()
    print("Evalutation of best performing model:")
    print(best_model.evaluate(X_test, Y_test))
    print("Best performing model chosen hyper-parameters:")
    print(best_run)
# Out:
# Using TensorFlow backend.
# >>> Imports:
# #coding=utf-8
#
# try:
#     import numpy as np
# except:
#     pass
#
# try:
#     from keras.datasets import mnist
# except:
#     pass
#
# try:
#     from tensorflow.keras.models import Sequential
# except:
#     pass
#
# try:
#     from tensorflow.keras.layers import Activation, Dense, Dropout
# except:
#     pass
#
# try:
#     from hyperas.distributions import uniform
# except:
#     pass
#
# try:
#     from hyperopt import STATUS_OK
# except:
#     pass
#
# try:
#     from keras.datasets import mnist
# except:
#     pass
#
# try:
#     from keras.utils import np_utils
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperopt import Trials, tpe
# except:
#     pass
#
# >>> Hyperas search space:
#
# def get_space():
#     return {
#         'Dropout': hp.uniform('Dropout', 0, 1),
#         'Dense': hp.choice('Dense', [256, 512, 1024]),
#         'Activation': hp.choice('Activation', ['relu', 'sigmoid']),
#         'Dropout_1': hp.uniform('Dropout_1', 0, 1),
#         'Dropout_2': hp.choice('Dropout_2', ['three', 'four']),
#         'add': hp.choice('add', [Dropout(0.5), Activation('linear')]),
#         'optimizer': hp.choice('optimizer', ['rmsprop', 'adam', 'sgd']),
#         'batch_size': hp.choice('batch_size', [64, 128]),
#     }
#
# >>> Data
#   1:
#   2:
#   3: import numpy as np
#   4: from keras.datasets import mnist
#   5: from keras.utils import np_utils
#   6:
#   7: x_train = np.zeros(100)
#   8: x_test = np.zeros(100)
#   9: y_train = np.zeros(100)
#  10: y_test = np.zeros(100)
#  11:
#  12: (x_train, y_train), (x_test, y_test) = mnist.load_data()
#  13: x_train = x_train.reshape(60000, 784)
#  14: x_test = x_test.reshape(10000, 784)
#  15: x_train = x_train.astype('float32')
#  16: x_test = x_test.astype('float32')
#  17: x_train /= 255
#  18: x_test /= 255
#  19: nb_classes = 10
#  20: y_train = np_utils.to_categorical(y_train, nb_classes)
#  21: y_test = np_utils.to_categorical(y_test, nb_classes)
#  22:
#  23:
#  24:
#  25:
#  26:
# >>> Resulting replaced keras model:
#
#    1: def keras_fmin_fnct(space):
#    2:
#    3:
#    4:
#    5:
#    6:     model = Sequential()
#    7:     model.add(Dense(512, input_shape=(784,)))
#    8:     model.add(Activation('relu'))
#    9:     model.add(Dropout(space['Dropout']))
#   10:     model.add(Dense(space['Dense']))
#   11:     model.add(Activation(space['Activation']))
#   12:     model.add(Dropout(space['Dropout_1']))
#   13:
#   14:     # If we choose 'four', add an additional fourth layer
#   15:     if space['Dropout_2'] == 'four':
#   16:         model.add(Dense(100))
#   17:
#   18:         # We can also choose between complete sets of layers
#   19:
#   20:         model.add(space['add'])
#   21:         model.add(Activation('relu'))
#   22:
#   23:     model.add(Dense(10))
#   24:     model.add(Activation('softmax'))
#   25:
#   26:     model.compile(loss='categorical_crossentropy', metrics=['accuracy'],
#   27:                   optimizer=space['optimizer'])
#   28:
#   29:     result = model.fit(x_train, y_train,
#   30:               batch_size=space['batch_size'],
#   31:               epochs=2,
#   32:               verbose=2,
#   33:               validation_split=0.1)
#   34:     #get the highest validation accuracy of the training epochs
#   35:     validation_acc = np.amax(result.history['val_accuracy'])
#   36:     print('Best validation acc of epoch:', validation_acc)
#   37:     return {'loss': -validation_acc, 'status': STATUS_OK, 'model': model}
#   38:
# Epoch 1/2
# 422/422 - 4s - loss: 1.7393 - accuracy: 0.4201 - val_loss: 0.8032 - val_accuracy: 0.8502
#
# Epoch 2/2
# 422/422 - 4s - loss: 0.9482 - accuracy: 0.6949 - val_loss: 0.4623 - val_accuracy: 0.8912
#
# Best validation acc of epoch:
# 0.8911666870117188
# Epoch 1/2
# 844/844 - 7s - loss: 2.2172 - accuracy: 0.2822 - val_loss: 0.6929 - val_accuracy: 0.8198
#
# Epoch 2/2
# 844/844 - 7s - loss: 1.5055 - accuracy: 0.4732 - val_loss: 0.5351 - val_accuracy: 0.8493
#
# Best validation acc of epoch:
# 0.8493333458900452
# Epoch 1/2
# 844/844 - 4s - loss: 1.9974 - accuracy: 0.2930 - val_loss: 0.6947 - val_accuracy: 0.8932
#
# Epoch 2/2
# 844/844 - 4s - loss: 1.2916 - accuracy: 0.5129 - val_loss: 0.3923 - val_accuracy: 0.9303
#
# Best validation acc of epoch:
# 0.9303333163261414
# Epoch 1/2
# 422/422 - 3s - loss: 0.7697 - accuracy: 0.7527 - val_loss: 0.1873 - val_accuracy: 0.9453
#
# Epoch 2/2
# 422/422 - 3s - loss: 0.2892 - accuracy: 0.9173 - val_loss: 0.1120 - val_accuracy: 0.9665
#
# Best validation acc of epoch:
# 0.9664999842643738
# Epoch 1/2
# 422/422 - 6s - loss: 0.5241 - accuracy: 0.8416 - val_loss: 0.1230 - val_accuracy: 0.9633
#
# Epoch 2/2
# 422/422 - 6s - loss: 0.1748 - accuracy: 0.9526 - val_loss: 0.0981 - val_accuracy: 0.9717
#
# Best validation acc of epoch:
# 0.971666693687439
# 100%|██████████| 5/5 [00:51<00:00, 10.27s/trial, best loss: -0.971666693687439]
# Evalutation of best performing model:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1182 - accuracy: 0.9638
# [0.11819132417440414, 0.9638000130653381]
# Best performing model chosen hyper-parameters:
# {'Activation': 1, 'Dense': 2, 'Dropout': 0.03323327852409652, 'Dropout_1': 0.0886198698550964, 'Dropout_2': 1, 'add': 0, 'batch_size': 1, 'optimizer': 0}
