# %%
    # import pandas as pd
    
    # import tensorflow as tf
    # from matplotlib import pyplot as plt
    # from sklearn.preprocessing import LabelEncoder
    # from sklearn.preprocessing import MinMaxScaler
    # from sklearn.model_selection import train_test_split
    # from sklearn.metrics import mean_squared_error
    # from tensorflow.keras.models import Sequential
    
    # from tensorflow.keras.layers import LSTM
    # from tensorflow.keras.preprocessing import timeseries_dataset_from_array

    # from hyperas import optim
    # from hyperas.distributions import choice, uniform
    # from hyperopt import Trials, STATUS_OK, tpe

# %%
def data():

    import numpy as np
    from keras.datasets import mnist
    from keras.utils import np_utils

    x_train = np.zeros(100)
    x_test = np.zeros(100)
    y_train = np.zeros(100)
    y_test = np.zeros(100)
    
    (x_train, y_train), (x_test, y_test) = mnist.load_data()
    x_train = x_train.reshape(60000, 784)
    x_test = x_test.reshape(10000, 784)
    x_train = x_train.astype('float32')
    x_test = x_test.astype('float32')
    x_train /= 255
    x_test /= 255
    nb_classes = 10
    y_train = np_utils.to_categorical(y_train, nb_classes)
    y_test = np_utils.to_categorical(y_test, nb_classes)
    return x_train, y_train, x_test, y_test

    return x_train, y_train, x_test, y_test

# %%
def create_model(x_train, y_train, x_test, y_test):

    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import Activation, Dense, Dropout
    from hyperas.distributions import uniform
    from hyperopt import STATUS_OK
    from keras.datasets import mnist
    from keras.utils import np_utils


    model = Sequential()
    model.add(Dense(512, input_shape=(784,)))
    model.add(Activation('relu'))
    model.add(Dropout({{uniform(0, 1)}}))
    model.add(Dense({{choice([256, 512, 1024])}}))
    model.add(Activation({{choice(['relu', 'sigmoid'])}}))
    model.add(Dropout({{uniform(0, 1)}}))

    # If we choose 'four', add an additional fourth layer
    if {{choice(['three', 'four'])}} == 'four':
        model.add(Dense(100))

        # We can also choose between complete sets of layers

        model.add({{choice([Dropout(0.5), Activation('linear')])}})
        model.add(Activation('relu'))

    model.add(Dense(10))
    model.add(Activation('softmax'))

    model.compile(loss='categorical_crossentropy', metrics=['accuracy'],
                  optimizer={{choice(['rmsprop', 'adam', 'sgd'])}})

    result = model.fit(x_train, y_train,
              batch_size={{choice([64, 128])}},
              epochs=2,
              verbose=2,
              validation_split=0.1)
    #get the highest validation accuracy of the training epochs
    print(result.history)
    validation_acc = np.amax(result.history['val_accuracy']) 
    print('Best validation acc of epoch:', validation_acc)
    return {'loss': -validation_acc, 'status': STATUS_OK, 'model': model}

# %%
if __name__ == '__main__':
    from hyperas import optim
    from hyperopt import Trials, tpe
    
    best_run, best_model = optim.minimize(model=create_model,
                                          data=data,
                                          algo=tpe.suggest,
                                          max_evals=5,
                                          trials=Trials(),
                                          notebook_name='test')



    X_train, Y_train, X_test, Y_test = data()
    print("Evalutation of best performing model:")
    print(best_model.evaluate(X_test, Y_test))
    print("Best performing model chosen hyper-parameters:")
    print(best_run)
# Out:
# >>> Imports:
# #coding=utf-8
#
# try:
#     import numpy as np
# except:
#     pass
#
# try:
#     from keras.datasets import mnist
# except:
#     pass
#
# try:
#     from keras.utils import np_utils
# except:
#     pass
#
# try:
#     from tensorflow.keras.models import Sequential
# except:
#     pass
#
# try:
#     from tensorflow.keras.layers import Activation, Dense, Dropout
# except:
#     pass
#
# try:
#     from hyperas.distributions import uniform
# except:
#     pass
#
# try:
#     from hyperopt import STATUS_OK
# except:
#     pass
#
# try:
#     from keras.datasets import mnist
# except:
#     pass
#
# try:
#     from keras.utils import np_utils
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperopt import Trials, tpe
# except:
#     pass
#
# >>> Hyperas search space:
#
# def get_space():
#     return {
#         'Dropout': hp.uniform('Dropout', 0, 1),
#         'Dense': hp.choice('Dense', [256, 512, 1024]),
#         'Activation': hp.choice('Activation', ['relu', 'sigmoid']),
#         'Dropout_1': hp.uniform('Dropout_1', 0, 1),
#         'Dropout_2': hp.choice('Dropout_2', ['three', 'four']),
#         'add': hp.choice('add', [Dropout(0.5), Activation('linear')]),
#         'optimizer': hp.choice('optimizer', ['rmsprop', 'adam', 'sgd']),
#         'batch_size': hp.choice('batch_size', [64, 128]),
#     }
#
# >>> Data
#   1:
#   2:
#   3: import numpy as np
#   4: from keras.datasets import mnist
#   5: from keras.utils import np_utils
#   6:
#   7: x_train = np.zeros(100)
#   8: x_test = np.zeros(100)
#   9: y_train = np.zeros(100)
#  10: y_test = np.zeros(100)
#  11:
#  12: (x_train, y_train), (x_test, y_test) = mnist.load_data()
#  13: x_train = x_train.reshape(60000, 784)
#  14: x_test = x_test.reshape(10000, 784)
#  15: x_train = x_train.astype('float32')
#  16: x_test = x_test.astype('float32')
#  17: x_train /= 255
#  18: x_test /= 255
#  19: nb_classes = 10
#  20: y_train = np_utils.to_categorical(y_train, nb_classes)
#  21: y_test = np_utils.to_categorical(y_test, nb_classes)
#  22:
#  23:
#  24:
#  25:
#  26:
# >>> Resulting replaced keras model:
#
#    1: def keras_fmin_fnct(space):
#    2:
#    3:
#    4:
#    5:
#    6:     model = Sequential()
#    7:     model.add(Dense(512, input_shape=(784,)))
#    8:     model.add(Activation('relu'))
#    9:     model.add(Dropout(space['Dropout']))
#   10:     model.add(Dense(space['Dense']))
#   11:     model.add(Activation(space['Activation']))
#   12:     model.add(Dropout(space['Dropout_1']))
#   13:
#   14:     # If we choose 'four', add an additional fourth layer
#   15:     if space['Dropout_2'] == 'four':
#   16:         model.add(Dense(100))
#   17:
#   18:         # We can also choose between complete sets of layers
#   19:
#   20:         model.add(space['add'])
#   21:         model.add(Activation('relu'))
#   22:
#   23:     model.add(Dense(10))
#   24:     model.add(Activation('softmax'))
#   25:
#   26:     model.compile(loss='categorical_crossentropy', metrics=['accuracy'],
#   27:                   optimizer=space['optimizer'])
#   28:
#   29:     result = model.fit(x_train, y_train,
#   30:               batch_size=space['batch_size'],
#   31:               epochs=2,
#   32:               verbose=2,
#   33:               validation_split=0.1)
#   34:     #get the highest validation accuracy of the training epochs
#   35:     print(result.history)
#   36:     validation_acc = np.amax(result.history['val_accuracy'])
#   37:     print('Best validation acc of epoch:', validation_acc)
#   38:     return {'loss': -validation_acc, 'status': STATUS_OK, 'model': model}
#   39:
# Epoch 1/2
# 422/422 - 5s - loss: 1.7504 - accuracy: 0.4130 - val_loss: 0.8346 - val_accuracy: 0.8482
#
# Epoch 2/2
# 422/422 - 4s - loss: 0.9694 - accuracy: 0.6885 - val_loss: 0.4698 - val_accuracy: 0.8907
#
# {'loss': [1.750365972518921, 0.969367504119873], 'accuracy': [0.4130370318889618, 0.688537061214447], 'val_loss': [0.8345900774002075, 0.46981507539749146], 'val_accuracy': [0.8481666445732117, 0.890666663646698]}
# Best validation acc of epoch:
# 0.890666663646698
# Epoch 1/2
# 844/844 - 7s - loss: 2.2087 - accuracy: 0.2838 - val_loss: 0.6800 - val_accuracy: 0.8417
#
# Epoch 2/2
# 844/844 - 9s - loss: 1.5275 - accuracy: 0.4620 - val_loss: 0.5471 - val_accuracy: 0.8518
#
# {'loss': [2.2087416648864746, 1.5275342464447021], 'accuracy': [0.2837963104248047, 0.4620000123977661], 'val_loss': [0.6799909472465515, 0.547086775302887], 'val_accuracy': [0.8416666388511658, 0.8518333435058594]}
# Best validation acc of epoch:
# 0.8518333435058594
# Epoch 1/2
# 844/844 - 4s - loss: 2.0028 - accuracy: 0.2886 - val_loss: 0.7560 - val_accuracy: 0.8712
#
# Epoch 2/2
# 844/844 - 3s - loss: 1.3127 - accuracy: 0.5110 - val_loss: 0.4062 - val_accuracy: 0.9302
#
# {'loss': [2.002819061279297, 1.312709927558899], 'accuracy': [0.2886296212673187, 0.5110185146331787], 'val_loss': [0.7559701204299927, 0.4062245190143585], 'val_accuracy': [0.8711666464805603, 0.9301666617393494]}
# Best validation acc of epoch:
# 0.9301666617393494
# Epoch 1/2
# 422/422 - 3s - loss: 0.7840 - accuracy: 0.7496 - val_loss: 0.1792 - val_accuracy: 0.9457
#
# Epoch 2/2
# 422/422 - 2s - loss: 0.2898 - accuracy: 0.9175 - val_loss: 0.1191 - val_accuracy: 0.9643
#
# {'loss': [0.7839522361755371, 0.2898004651069641], 'accuracy': [0.7496481537818909, 0.9175184965133667], 'val_loss': [0.1792353093624115, 0.1191483661532402], 'val_accuracy': [0.9456666707992554, 0.9643333554267883]}
# Best validation acc of epoch:
# 0.9643333554267883
# Epoch 1/2
# 422/422 - 5s - loss: 0.5536 - accuracy: 0.8325 - val_loss: 0.1377 - val_accuracy: 0.9588
#
# Epoch 2/2
# 422/422 - 6s - loss: 0.1861 - accuracy: 0.9496 - val_loss: 0.1011 - val_accuracy: 0.9705
#
# {'loss': [0.5535686016082764, 0.186109721660614], 'accuracy': [0.8325185179710388, 0.9495740532875061], 'val_loss': [0.13771237432956696, 0.10111036896705627], 'val_accuracy': [0.9588333368301392, 0.9704999923706055]}
# Best validation acc of epoch:
# 0.9704999923706055
# 100%|██████████| 5/5 [00:52<00:00, 10.49s/trial, best loss: -0.9704999923706055]
# Evalutation of best performing model:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1278 - accuracy: 0.9608
# [0.12782840430736542, 0.9607999920845032]
# Best performing model chosen hyper-parameters:
# {'Activation': 1, 'Dense': 2, 'Dropout': 0.03323327852409652, 'Dropout_1': 0.0886198698550964, 'Dropout_2': 1, 'add': 0, 'batch_size': 1, 'optimizer': 0}
